# %%
import pandas as pd
import seaborn as sb
import matplotlib as mp

# %%
import numpy as np

# %%
# PATH_TO_DATA = "C:\\Users\\zndy\\notebooks\\notebooks\\titanic\\train.csv"
# PATH_TO_TEST = "C:\\Users\\zndy\\notebooks\\notebooks\\titanic\\test.csv"
PATH_TO_DATA = "C:\\Users\\email\\OneDrive\\Изображения\\Документы\\Datasets\\titanic\\train.csv"
PATH_TO_TEST = "C:\\Users\\email\\OneDrive\\Изображения\\Документы\\Datasets\\titanic\\test.csv"
df = pd.read_csv(PATH_TO_DATA)
df_test = pd.read_csv(PATH_TO_TEST)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Survived"] == 1].describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
df[df["Survived"] == 0].describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[(df["Survived"] == 0) & (df["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.drop('Name', axis=1, inplace=True)

# %%
df.drop('Ticket', axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500   NaN
# 1              2         1       1  female  38.0      1      0  71.2833   C85
# 2              3         1       3  female  26.0      0      0   7.9250   NaN
# 3              4         1       1  female  35.0      1      0  53.1000  C123
# 4              5         0       3    male  35.0      0      0   8.0500   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2    male  27.0      0      0  13.0000   NaN
# 887          888         1       1  female  19.0      0      0  30.0000   B42
# 888          889         0       3  female   NaN      1      2  23.4500   NaN
# 889          890         1       1    male  26.0      0      0  30.0000  C148
# 890          891         0       3    male  32.0      0      0   7.7500   NaN
#
#     Embarked
# 0          S
# ...

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
def input_data(df):
    df_copy = df.copy()
    
    # Заполнение категориальных переменных
    categorical_cols = df_copy.select_dtypes(include=['object', 'category']).columns
    for col in categorical_cols:
        if df_copy[col].isna().any():
            # Безопасное заполнение модой
            mode_values = df_copy[col].mode()
            fill_value = mode_values.iloc[0] if not mode_values.empty else 'Unknown'
            df_copy[col] = df_copy[col].fillna(fill_value)
    
    # Заполнение числовых переменных
    numerical_cols = df_copy.select_dtypes(include=['number']).columns
    for col in numerical_cols:
        if df_copy[col].isna().any():
            # Безопасное заполнение медианой
            fill_value = df_copy[col].median() if not df_copy[col].dropna().empty else 0
            df_copy[col] = df_copy[col].fillna(fill_value)
    
    return df_copy

# %%
useless_col = ['Name','Ticket','Cabin']
df_test.drop(useless_col, axis=1, inplace=True)

# %%
df_full = input_data(df)
df_test_full = input_data(df_test)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
sb.catplot(x='Sex', hue='Survived', data=df_full, kind='count')

# %%
df_test_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    object
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Fare         418 non-null    float64
#  7   Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 26.3+ KB

# %%
sb.catplot(x='Pclass', hue='Survived', data=df_full, kind='count')

# %%
sb.catplot(x='Pclass', data=df_full, kind='count')

# %%
sb.catplot(x='Sex', y='Survived', col='Pclass', data=df_full, kind='bar')

# %%
sb.catplot(x='SibSp', data=df_full, hue='Survived', kind='count')

# %%
sb.catplot(x='Parch', data=df_full, hue='Survived', kind='count')

# %%
df_full['Family_size'] = df_full['Parch'] + df_full['SibSp']
df_test_full['Family_size'] = df_test_full['Parch'] + df_test_full['SibSp']

df_full.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  Family_size
# 0        S            1
# 1        C            1
# 2        S            0
# 3        S            1
# 4        S            0

# %%
sb.catplot(x='Family_size', data=df_full, hue='Survived', kind='count')

# %%
df_full.to_csv('train_imputed.csv')
df_test_full.to_csv('test_imputed.csv')

# %%
#создание булева вектора
(df_full['Sex'] == 'male')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
(df_full['Sex'] == 'male') & (df_full['Pclass'] == 3)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
# выбираем всех мужчин из третьего класса и говорим, что они бы не выжили

simple_pred = (~((df_test_full['Sex'] == 'male') & (df_test_full['Pclass'] == 3))).astype(int).values

# %%
def make_prediction_file(prediction, test_data, name):
    result = pd.DataFrame({'PassengerId' : test_data.reset_index()['PassengerId'], 'Survived': prediction})
    result.to_csv(name, index=False)

# %%
make_prediction_file(simple_pred, df_test, 'titanic_simple_baseline.csv')

# %% [markdown]
# ## Кодирование категориальных признаков (one-hot-encoding)

# %%
y_train = df['Survived']
train_sep = df.drop(columns=['Survived'])

# %%
X_train
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  \
# 0              1       0.0       3  22.0      1      0   7.2500      True
# 1              2       1.0       1  38.0      1      0  71.2833     False
# 2              3       1.0       3  26.0      0      0   7.9250     False
# 3              4       1.0       1  35.0      1      0  53.1000     False
# 4              5       0.0       3  35.0      0      0   8.0500      True
# ..           ...       ...     ...   ...    ...    ...      ...       ...
# 885          886       0.0       3  39.0      0      5  29.1250     False
# 886          887       0.0       2  27.0      0      0  13.0000      True
# 887          888       1.0       1  19.0      0      0  30.0000     False
# 888          889       0.0       3   NaN      1      2  23.4500     False
# 889          890       1.0       1  26.0      0      0  30.0000      True
#
#      Embarked_Q  Embarked_S
# 0         False        True
# ...

# %%
def encode_categorial(df_train, df_test):
    test_start_ind = df_train.index[-1]

    concated_df = pd.concat([df_train, df_test], sort=False)

    encoded_df = pd.get_dummies(concated_df, drop_first=True)

    df_train_encoded, df_test_encoded = encoded_df.iloc[:test_start_ind, :], encoded_df.iloc[test_start_ind:, :]

    return df_train_encoded, df_test_encoded

# %%
X_train, X_test = encode_categorial(df, df_test)

y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890 entries, 0 to 889
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  890 non-null    int64
#  1   Survived     890 non-null    float64
#  2   Pclass       890 non-null    int64
#  3   Age          713 non-null    float64
#  4   SibSp        890 non-null    int64
#  5   Parch        890 non-null    int64
#  6   Fare         890 non-null    float64
#  7   Sex_male     890 non-null    bool
#  8   Embarked_Q   890 non-null    bool
#  9   Embarked_S   890 non-null    bool
# dtypes: bool(3), float64(3), int64(4)
# memory usage: 58.2 KB

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_clf = DecisionTreeClassifier()

# %%
# %%time
y_train.drop(labels=0, axis=0, inplace=True)

dt_clf.fit(X_train, y_train)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 45.7 ms
# DecisionTreeClassifier()

# %%
pred_dt_simple = dt_clf.predict(X_test)

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image, display

def vizualize_tree(clf, X, file_name):

    export_graphviz(clf, feature_names=X.columns, out_file = file_name + '.dot', filled=True)

    # !dot -Tpng {file_name}.dot -o {file_name}.png

    display(Image(filename=file_name + '.png'))

# %%
vizualize_tree(dt_clf, X_train, 'tree')
# Out:
# "dot" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 vizualize_tree(dt_clf, X_train, 'tree')
#
# Cell In[159], line 10, in vizualize_tree(clf, X, file_name)
#       6 export_graphviz(clf, feature_names=X.columns, out_file = file_name + '.dot', filled=True)
#       8 get_ipython().system('dot -Tpng {file_name}.dot -o {file_name}.png')
# ---> 10 display(Image(filename=file_name + '.png'))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# ...
